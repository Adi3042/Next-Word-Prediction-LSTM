# %%
import tensorflow as tf
import pickle
import json
import time
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# Load model
model = tf.keras.models.load_model("saved_model/next_word_lstm.keras")

# Load tokenizer
with open("saved_model/tokenizer.pkl", "rb") as f:
    tokenizer = pickle.load(f)

# Load config
with open("saved_model/config.json", "r") as f:
    config = json.load(f)

max_len = config["max_len"]
# vocab_size = config["vocab_size"]

# %%
tokenizer.word_index.items()
# Out:
# dict_items([('the', 1), ('of', 2), ('and', 3), ('a', 4), ('is', 5), ('to', 6), ('in', 7), ('with', 8), ('that', 9), ('are', 10), ('cosmic', 11), ('it', 12), ('this', 13), ('not', 14), ('from', 15), ('universe', 16), ('these', 17), ('om', 18), ('we', 19), ('by', 20), ('forces', 21), ('our', 22), ('at', 23), ('sound', 24), ('its', 25), ('within', 26), ('cosmics', 27), ('fields', 28), ('waves', 29), ('all', 30), ('consciousness', 31), ('itself', 32), ('symphony', 33), ('1', 34), ('2', 35), ('song', 36), ('human', 37), ('understanding', 38), ('fundamental', 39), ('two', 40), ('or', 41), ('which', 42), ('represents', 43), ('they', 44), ('resonant', 45), ('existence', 46), ('galactic', 47), ('–', 48), ('every', 49), ('nuclear', 50), ('stars', 51), ('but', 52), ('vibration', 53), ('as', 54), ('into', 55), ('state', 56), ('merely', 57), ('light', 58), ('dynamic', 59), ('phenomena', 60), ('moment', 61), ('has', 62), ('science', 63), ('experiential', 64), ('profound', 65), ('”', 66), ('galaxy', 67), ('gravitational', 68), ('concept', 69), ('manifestation', 70), ('radio', 71), ('an', 72), ('measurable', 73), ('more', 74), ('spectrum', 75), ('spacetime', 76), ('stellar', 77), ('plasma', 78), ('black', 79), ('holes', 80), ('curve', 81), ('deep', 82), ('m', 83), ('pronounced', 84), ('representing', 85), ('silence', 86), ('quest', 87), ('for', 88), ('connection', 89), ('singing', 90), ('first', 91), ('wonder', 92), ('what', 93), ('nature', 94), ('cosmos', 95), ('place', 96), ('rivers', 97), ('exploration', 98), ('objective', 99), ('river', 100), ('other', 101), ('subjective', 102), ('spirituality', 103), ('philosophical', 104), ('foundational', 105), ('truth', 106), ('single', 107), ('reality', 108), ('concepts', 109), ('beyond', 110), ('rays', 111), ('quantum', 112), ('yet', 113), ('aum', 114), ('primordial', 115), ('indian', 116), ('vibrational', 117), ('syllable', 118), ('sonic', 119), ('absolute', 120), ('between', 121), ('fundamentally', 122), ('conscious', 123), ('term', 124), ('represent', 125), ('dynamics', 126), ('same', 127), ('map', 128), ('part', 129), ('chapter', 130), ('than', 131), ('“space', 132), ('must', 133), ('be', 134), ('mere', 135), ('radiation', 136), ('most', 137), ('gravity', 138), ('electromagnetism', 139), ('force', 140), ('static', 141), ('field', 142), ('underlying', 143), ('direct', 144), ('fusion', 145), ('emitting', 146), ('vibrations', 147), ('planets', 148), ('magnetospheres', 149), ('their', 150), ('magnetic', 151), ('neutron', 152), ('pulsars', 153), ('new', 154), ('deepest', 155), ('medium', 156), ('through', 157), ('own', 158), ('symbol', 159), ('understand', 160), ('waking', 161), ('dreaming', 162), ('sleep', 163), ('transcendent', 164), ('thus', 165), ('manifest', 166), ('three', 167), ('u', 168), ('creation', 169), ('mouth', 170), ('preservation', 171), ('dissolution', 172), ('ground', 173), ('endless', 174), ('chant', 175), ('prologue', 176), ('vast', 177), ('cold', 178), ('emptiness', 179), ('punctuated', 180), ('points', 181), ('living', 182), ('breathing', 183), ('entity—a', 184), ('grand', 185), ('tapestry', 186), ('woven', 187), ('stretch', 188), ('limits', 189), ('perception', 190), ('ancestors', 191), ('gazed', 192), ('upward', 193), ('celestial', 194), ('vault', 195), ('question', 196), ('pulsed', 197), ('psyche', 198), ('traveled', 199), ('along', 200), ('great', 201), ('seemingly', 202), ('divergent', 203), ('one', 204), ('external', 205), ('meticulous', 206), ('observation', 207), ('measurement', 208), ('theorization', 209), ('physical', 210), ('internal', 211), ('intuitive', 212), ('seeking', 213), ('meaning', 214), ('essay', 215), ('seeks', 216), ('demonstrate', 217), ('fact', 218), ('tributaries', 219), ('ocean', 220), ('vehicle', 221), ('examination', 222), ('“cosmics', 223), ('refer', 224), ('totality', 225), ('entities', 226), ('energies', 227), ('radiations', 228), ('constitute', 229), ('fabric', 230), ('includes', 231), ('known—electromagnetic', 232), ('spectra', 233), ('neutrino' ...

# %%
index_to_word = {index: word for word, index in tokenizer.word_index.items()}
index_to_word
# Out:
# {1: 'the',
#  2: 'of',
#  3: 'and',
#  4: 'a',
#  5: 'is',
#  6: 'to',
#  7: 'in',
#  8: 'with',
#  9: 'that',
#  10: 'are',
#  11: 'cosmic',
#  12: 'it',
#  13: 'this',
#  14: 'not',
#  15: 'from',
#  16: 'universe',
#  17: 'these',
#  18: 'om',
#  19: 'we',
#  20: 'by',
#  21: 'forces',
#  22: 'our',
#  23: 'at',
#  24: 'sound',
#  25: 'its',
#  26: 'within',
#  27: 'cosmics',
#  28: 'fields',
#  29: 'waves',
#  30: 'all',
#  31: 'consciousness',
#  32: 'itself',
#  33: 'symphony',
#  34: '1',
#  35: '2',
#  36: 'song',
#  37: 'human',
#  38: 'understanding',
#  39: 'fundamental',
#  40: 'two',
#  41: 'or',
#  42: 'which',
#  43: 'represents',
#  44: 'they',
#  45: 'resonant',
#  46: 'existence',
#  47: 'galactic',
#  48: '–',
#  49: 'every',
#  50: 'nuclear',
#  51: 'stars',
#  52: 'but',
#  53: 'vibration',
#  54: 'as',
#  55: 'into',
#  56: 'state',
#  57: 'merely',
#  58: 'light',
#  59: 'dynamic',
#  60: 'phenomena',
#  61: 'moment',
#  62: 'has',
#  63: 'science',
#  64: 'experiential',
#  65: 'profound',
#  66: '”',
#  67: 'galaxy',
#  68: 'gravitational',
#  69: 'concept',
#  70: 'manifestation',
#  71: 'radio',
#  72: 'an',
#  73: 'measurable',
#  74: 'more',
#  75: 'spectrum',
#  76: 'spacetime',
#  77: 'stellar',
#  78: 'plasma',
#  79: 'black',
#  80: 'holes',
#  81: 'curve',
#  82: 'deep',
#  83: 'm',
#  84: 'pronounced',
#  85: 'representing',
#  86: 'silence',
#  87: 'quest',
#  88: 'for',
#  89: 'connection',
#  90: 'singing',
#  91: 'first',
#  92: 'wonder',
#  93: 'what',
#  94: 'nature',
#  95: 'cosmos',
#  96: 'place',
#  97: 'rivers',
#  98: 'exploration',
#  99: 'objective',
#  100: 'river',
#  101: 'other',
#  102: 'subjective',
#  103: 'spirituality',
#  104: 'philosophical',
#  105: 'foundational',
#  106: 'truth',
#  107: 'single',
#  108: 'reality',
#  109: 'concepts',
#  110: 'beyond',
#  111: 'rays',
#  112: 'quantum',
#  113: 'yet',
#  114: 'aum',
#  115: 'primordial',
#  116: 'indian',
#  117: 'vibrational',
#  118: 'syllable',
#  119: 'sonic',
#  120: 'absolute',
#  121: 'between',
#  122: 'fundamentally',
#  123: 'conscious',
#  124: 'term',
#  125: 'represent',
#  126: 'dynamics',
#  127: 'same',
#  128: 'map',
#  129: 'part',
#  130: 'chapter',
#  131: 'than',
#  132: '“space',
#  133: 'must',
#  134: 'be',
#  135: 'mere',
#  136: 'radiation',
#  137: 'most',
#  138: 'gravity',
#  139: 'electromagnetism',
#  140: 'force',
#  141: 'static',
#  142: 'field',
#  143: 'underlying',
#  144: 'direct',
#  145: 'fusion',
#  146: 'emitting',
#  147: 'vibrations',
#  148: 'planets',
#  149: 'magnetospheres',
#  150: 'their',
#  151: 'magnetic',
#  152: 'neutron',
#  153: 'pulsars',
#  154: 'new',
#  155: 'deepest',
#  156: 'medium',
#  157: 'through',
#  158: 'own',
#  159: 'symbol',
#  160: 'understand',
#  161: 'waking',
#  162: 'dreaming',
#  163: 'sleep',
#  164: 'transcendent',
#  165: 'thus',
#  166: 'manifest',
#  167: 'three',
#  168: 'u',
#  169: 'creation',
#  170: 'mouth',
#  171: 'preservation',
#  172: 'dissolution',
#  173: 'ground',
#  174: 'endless',
#  175: 'chant',
#  176: 'prologue',
#  177: 'vast',
#  178: 'cold',
#  179: 'emptiness',
#  180: 'punctuated',
#  181: 'points',
#  182: 'living',
#  183: 'breathing',
#  184: 'entity—a',
#  185: 'grand',
#  186: 'tapestry',
#  187: 'woven',
#  188: 'stretch',
#  189: 'limits',
#  190: 'perception',
#  191: 'ancestors',
#  192: 'gazed',
#  193: 'upward',
#  194: 'celestial',
#  195: 'vault',
#  196: 'question',
#  197: 'pulsed',
#  198: 'psyche',
#  199: 'traveled',
#  200: 'along',
#  201: 'great',
#  202: 'seemingly',
#  203: 'divergent',
#  204: 'one',
#  205: 'external',
#  206: 'meticulous',
#  207: 'observation',
#  208: 'measurement',
#  209: 'theorization',
#  210: 'physical',
#  211: 'internal',
#  212: 'intuitive',
#  213: 'seeking',
#  214: 'meaning',
#  215: 'essay',
#  216: 'seeks',
#  217: 'demonstrate',
#  218: 'fact',
#  219: 'tributaries',
#  220: 'ocean',
#  221: 'vehicle',
#  222: 'examination',
#  223: '“cosmics',
#  224: 'refer',
#  225: 'totality',
#  226: 'entities',
#  227: 'energies',
#  228: 'radiations',
#  229: 'constitute',
#  230: 'fabric',
#  231: 'includes',
#  232: 'known—electromagnetic',
#  233: 'spectra',
#  234: 'neutrino',
#  235: 'fluxes',
#  236: 'dark',
#  237: 'matter',
#  238: 'halos',
#  239: 'vacuum',
#  240: 'fluctuations—and',
#  241: 'unknown',
#  242: '“om”',
#  243: 'engage',
#  244: 'ancient',
#  245: 'wisdom',
#  246: 'seed',
#  247: 'said',
#  248: 'have',
#  249: 'emerged',
#  250: 'signature',
#  251: 'bridge',
#  252: 'individual',
#  253: 'glance',
#  254: 'inhabit',
#  255: 'separate',
#  256: 'realms—one',
#  257: 'domain',
#  258: 'telescopes',
#  259: 'particle',
#  260: 'accelerators',
#  261: 'meditation',
#  262: 'halls',
#  263: 'sacred',
#  264: 'texts',
#  265: 'deeper',
#  266: 'investigation',
#  267: 'reveals',
#  268: 'startling',
#  269: 'convergence',
#  270: 'both',
#  271: 'point',
#  272: 'energetic',
#  273: 'interconnected',
#  274: 'manner',
#  275: 'redefines',
#  276: 'attempt',
#  277: '“prove”',
#  278: 'reduce',
#  279: 'metaphor',
#  280: 'rather',
#  281: 'integrative',
#  282: 'inquiry',
#  283: 'positing',
#  284: 'exterior',
#  285: 'universal',
#  286: 'while',
#  287: 'interior',
#  288: 'gateway',
#  289: 'those',
#  290: 'together',
#  291: 'form',
#  292: 'complementary',
#  293: 'offering',
#  294: 'holistic',
#  295: 'vision',
#  296: 'very',
#  297: 'i',
#  298: 'realm',
#  299: 'defining',
#  300: 'just',
#  301: 'stuff”',
#  302: '“cosmics”',
#  303: 'liberated',
#  304: 'narrow',
#  305: 'association',
#  306: 'encompasses',
#  307: 'hierarchical',
#  308: 'interpenetrating',
#  309: 'existences',
#  310: 'shape',
#  311: 'aspect',
#  312: 'level',
#  313: 'four',
#  314: 'known',
#  315: 'mediated',
#  316: 'permeating',
#  317: 'strong',
#  318: 'weak',
#  319: 'primary',
#  320: 'architects',
#  321: 'structure',
#  322: 'sculpts',
#  323: 'galaxies',
#  324: 'clusters',
#  325: 'governs',
#  326: 'chemistry',
#  327: 'life',
#  328: 'forge',
#  329: 'atoms',
#  330: 'cores',
#  331: 'vibrating',
#  332: 'hypothesized',
#  333: 'unified',
#  334: '“theory',
#  335: 'everything”',
#  336: 'sought',
#  337: 'modern',
#  338: 'physics',
#  339: 'suggests',
#  340: 'manifestations',
#  341: 'superforce—a',
#  342: 'resonance',
#  343: 'idea',
#  344: 'unitary',
#  345: 'source',
#  346: 'symbolized',
#  347: 'phenomenological',
#  348: 'menagerie',
#  349: 'upon',
#  350: 'theoretic',
#  351: 'canvas',
#  352: 'plays',
#  353: 'breathtaking',
#  354: 'array',
#  355: 'balls',
#  356: 'gas',
#  357: 'spheres',
#  358: 'undergoing',
#  359: 'oscillating',
#  360: 'complex',
#  361: 'modes',
#  362: 'asteroseismology',
#  363: 'broad',
#  364: 'gamma',
#  365: 'each',
#  366: 'star',
#  367: '“voice”',
#  368: 'chorus',
#  369: 'like',
#  370: 'jupiter',
#  371: 'saturn',
#  372: 'emit',
#  373: 'powerful',
#  374: 'bursts',
#  375: 'generated',
#  376: 'interaction',
#  377: 'solar',
#  378: 'wind',
#  379: 'random',
#  380: 'noises',
#  381: 'structured',
#  382: 'periodic',
#  383: 'emissions',
#  384: 'akin',
#  385: 'whistlers',
#  386: 'drums',
#  387: 'ultimate',
#  388: 'metronomes',
#  389: 'incredibly',
#  390: 'dense',
#  391: 'remnants',
#  392: 'spin',
#  393: 'periods',
#  394: 'ranging',
#  395: 'milliseconds',
#  396: 'seconds',
#  397: 'beams',
#  398: 'stability',
#  399: 'rivals',
#  400: 'atomic',
#  401: 'clocks',
#  402: 'precise',
#  403: 'rhythmic',
#  404: 'pulses',
#  405: 'literal',
#  406: 'ticks',
#  407: 'clockwork',
#  408: 'ordered',
#  409: 'cyclical',
#  410: 'discovery',
#  411: 'ligo',
#  412: 'virgo',
#  413: 'observatories',
#  414: 'opened',
#  415: 'sense—',
#  416: 'hearing',
#  417: 'merger',
#  418: 'creates',
#  419: 'ripples',
#  420: 'propagating',
#  421: 'speed',
#  422: '“chirps”',
#  423: '“thuds”',
#  424: 'notes',
#  425: 'ringing',
#  426: 'interstellar',
#  427: 'intergalactic',
#  428: 'space',
#  429: 'empty',
#  430: 'filled',
#  431: 'tenuous',
#  432: 'dust',
#  433: 'grains',
#  434: 'molecules',
#  435: 'propagates',
#  436: 'filters',
#  437: 'modulates',
#  438: '“air”',
#  439: 'travels',
#  440: 'complete',
#  441: 'frequencies',
#  442: 'damping',
#  443: 'effects',
#  444: 'ii',
#  445: 'depth',
#  446: 'vedic',
#  447: 'yogic',
#  448: 'corpus',
#  449: 'experience',
#  450: 'mystical',
#  451: 'delve',
#  452: 'roots',
#  453: 'primarily',
#  454: 'traditions',
#  455: 'vedanta',
#  456: 'yoga',
#  457: 'etymology',
#  458: 'symbolism',
#  459: 'often',
#  460: 'written',
#  461: 'sanskrit',
#  462: 'ॐ',
#  463: 'visual',
#  464: 'glyph',
#  465: 'symbolic',
#  466: 'curves',
#  467: 'states',
#  468: 'bottom',
#  469: 'middle',
#  470: 'upper',
#  471: 'crescent',
#  472: 'above',
#  473: 'illusion',
#  474: 'maya',
#  475: 'dot',
#  476: 'bindu',
#  477: 'fourth',
#  478: 'turiya—pure',
#  479: 'non',
#  480: 'dual',
#  481: 'encapsulates',
#  482: 'entire',
#  483: 'unmanifest',
#  484: 'phonetic',
#  485: 'components',
#  486: 'analyzed',
#  487: 'triad',
#  488: 'अ',
#  489: '“ah”',
#  490: 'open',
#  491: 'throat',
#  492: 'beginning',
#  493: 'brahma',
#  494: 'creator',
#  495: 'originates',
#  496: 'back',
#  497: 'associated',
#  498: 'physicality',
#  499: 'उ',
#  500: '“oo',
#  501: 'flowing',
#  502: 'forward',
#  503: 'continuation',
#  504: 'vishnu',
#  505: 'preserver',
#  506: 'sustaining',
#  507: 'म्',
#  508: '“mm”',
#  509: 'closed',
#  510: 'lips',
#  511: 'completion',
#  512: 'shiva',
#  513: 'dissolver',
#  514: 'integration',
#  515: 'return',
#  516: 'turiyā',
#  517: 'following',
#  518: 'audible',
#  519: 'absence',
#  520: 'culmination—the',
#  521: 'transcendental',
#  522: 'sounds',
#  523: 'emerge',
#  524: 'dissolve',
#  525: 'brahman',
#  526: 'pure',
#  527: 'attributes',
#  528: 'word',
#  529: 'process',
#  530: 'epilogue',
#  531: 'silent',
#  532: 'thrums',
#  533: 'bass',
#  534: 'merging',
#  535: 'rings',
#  536: 'metallic',
#  537: 'chimes',
#  538: 'whispers',
#  539: 'winds',
#  540: 'hums',
#  541: 'microwave',
#  542: 'echo',
#  543: 'birth',
#  544: 'cosmics—the',
#  545: 'soul',
#  546: 'moments',
#  547: 'quiet',
#  548: 'contemplation',
#  549: 'intones',
#  550: 'begins',
#  551: 'belly',
#  552: 'material',
#  553: 'rises',
#  554: 'heart',
#  555: 'feeling',
#  556: 'dissolves',
#  557: 'crown',
#  558: 'om—the',
#  559: 'key',
#  560: 'poised',
#  561: 'unique',
#  562: 'history',
#  563: 'where',
#  564: 'songs',
#  565: 'can',
#  566: 'heard',
#  567: 'harmonious',
#  568: 'whole',
#  569: 'telescope',
#  570: 'mantra',
#  571: 'equation',
#  572: 'prayer',
#  573: 'converging',
#  574: 'tell',
#  575: 'us',
#  576: 'story',
#  577: 'live',
#  578: 'unimaginable',
#  579: 'dynamism',
#  580: 'intelligence',
#  581: 'dance',
#  582: 'audience',
#  583: 'singers',
#  584: 'act',
#  585: 'curiosity',
#  586: 'compassion',
#  587: 'participation',
#  588: 'creative',
#  589: 'vibratory',
#  590: 'flow',
#  591: 'know',
#  592: 'score',
#  593: 'find',
#  594: 'note',
#  595: 'knowing',
#  596: 'being',
#  597: 'may',
#  598: 'finally',
#  599: 'come',
#  600: 'home',
#  601: 'beautiful',
#  602: 'listening',
#  603: 'ever',
#  604: 'forms'}

# %%
def predict_next_words_realtime(text, num_words=20, delay=0.2):
    print(text, end=" ", flush=True)

    # Store generated text (keeps growing)
    generated_text = text

    # Loop to generate required number of words
    for _ in range(num_words):
        # Convert current text into token sequence
        token_text = tokenizer.texts_to_sequences([generated_text])[0]

        # Pad sequence to match training input length
        padded_token_text = pad_sequences([token_text], maxlen=max_len, padding='pre')

        # Predict probabilities for next word
        preds = model.predict(padded_token_text, verbose=0)

        # Get index of word with highest probability
        predicted_index = np.argmax(preds)

        # Convert predicted index back to word
        predicted_word = index_to_word.get(predicted_index)

        # Stop if no valid word is found
        if predicted_word is None:
            break

        # Append predicted word to generated text
        generated_text += " " + predicted_word

        # Print word immediately (real-time effect)
        print(predicted_word, end=" ", flush=True)

        time.sleep(delay)

    print()  # new line at end

# %%
# Seed text to start prediction
seed_text = "Three Phonetic Components"
predict_next_words_realtime(seed_text, num_words=30, delay=0.2)
# Out:
# Three Phonetic Components a mystical syllable we must delve into its philosophical roots primarily within the indian traditions of vedanta and yoga is the river of science the meticulous observation measurement and theorization
